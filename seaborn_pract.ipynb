#  -1.58179114 -1.92528041 -2.23033213 -2.49085604 -2.70165086 -2.85850816
#  -2.95829632 -2.99902312 -2.97987546 -2.90123562 -2.7646736  -2.57291583
#  -2.32979069 -2.04015207 -1.70978253 -1.34527776 -0.95391499 -0.54350763
#  -0.12224934  0.30144963  0.71913025  1.12245369  1.50336773  1.85426755
#   2.16814756  2.43874124  2.66064631  2.82943248  2.94173001  2.99529692
#   2.98906376  2.92315497  2.7988864   2.61873903  2.38630943  2.106238
#   1.78411624  1.42637522  1.04015712  0.63317263  0.21354707 -0.21034188
#  -0.63003143 -1.03714262 -1.42354761 -1.78153197 -2.10394866 -2.38436073
#  -2.61716987 -2.79772812 -2.92243068 -2.98878793 -2.99547505 -2.94235855
#  -2.83049888 -2.66212927 -2.44061117 -2.17036711 -1.85679242 -1.50614751
#  -1.12543288 -0.72224938 -0.30464641  0.11903872  0.54034728  0.95086799
#   1.34240495  1.70714126  2.03779508  2.32776503  2.57126195  2.76342451
#   2.90041626  2.9795022   2.9991034   2.95882854  2.85948168  2.70304626
#   2.49264546  2.23247985  1.92774354  1.58452051  1.20966306  0.81065512
#   0.39546272 -0.02762496 -0.45016111 -0.86370995]

# %% [markdown]
# # Basically, Seaborn splits the Matplotlib parameters into two groups−
#
# **1)Plot styles**
#
# **2)Plot scale**

# %% [markdown]
# Darkgrid
#
# Whitegrid
#
# Dark
#
# White
#
#
# Ticks
#
# The default theme of the plot will be darkgrid which we have seen in the previous example

# %%
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sb.set_style("whitegrid")
sinplot()
plt.show()

# %%
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sb.set_style("white")
sinplot()
sb.despine()
plt.show()

# %%
sb.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sb.set_style("darkgrid", {'axes.axisbelow': False})
sinplot()
sb.despine()
plt.show()

# %%
def sinplot(flip = 1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sb.set_style("white")
sb.set_palette("husl")
sinplot()
plt.show()

# %%
sb.color_palette()
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.9082572436765556, 0.40195790729656516, 0.9576909250290225)]

# %%
df1 = sb.load_dataset('iris')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.distplot(df['total_bill'])
plt.show()
# Out:
# C:\Users\vengadesh\AppData\Local\Temp\ipykernel_11956\3702132133.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['total_bill'])

# %%
sb.jointplot(x = 'total_bill',y = 'tip',data = df)
plt.show()

# %%
sb.jointplot(x = 'total_bill',y = 'tip',data = df,kind='hex')
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.set_style("ticks")
sb.pairplot(df,hue = 'smoker',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
sb.stripplot(x = "smoker", y = "tip", data = df)
plt.show()

# %%
g = sb.FacetGrid(df, col = "time")
# g.map(plt.hist, "tip")
# plt.show()

# %%
# g = sb.FacetGrid(df, col = "time")
g.map(plt.hist, "tip")
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
g = sb.PairGrid(df)
# g.map(plt.scatter);
# plt.show()

# %%
# g = sb.PairGrid(df)
g.map(plt.scatter);
plt.show()

# %%
g = sb.PairGrid(df)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);
plt.show()

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# draw lineplot 
sb.lineplot(x="tip", y="total_bill", data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# draw lineplot 
sb.lineplot(x="tip", y="total_bill", data=df) 
  
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
  
plt.show()

# %%
sb.lineplot(x="tip", y="total_bill", data=df)
plt.title("sample")
plt.show()

# %%
sb.lineplot(x="tip", y="total_bill", data=df)
plt.title("sample")
plt.xlim(5)
plt.show()

# %% [markdown]
# **Changing Figure Aesthetic**
#
#
# set_style() method is used to set the aesthetic of the plot. It means it affects things like the color of the axes, whether the grid is active or not, or other aesthetic elements.
#
# There are five themes available in Seaborn.
#
#
#
# -darkgrid
# -whitegrid
# -dark
# -white
# -ticks

# %%
sb.lineplot(x="tip", y="total_bill", data=df)
plt.title("sample")
sb.set_style("dark")
plt.show()

# %%
sb.lineplot(x="tip", y="total_bill", data=df)
plt.title("sample")
sb.despine()
plt.show()

# %% [markdown]
# **Changing the figure Size**
#
# figure() method creates a new figure of the specified size passed in the figsize parameter.

# %%
plt.figure(figsize = (6, 4))
sb.lineplot(x="tip", y="total_bill", data=df)
plt.title("sample")
plt.show()

# %% [markdown]
# **Scaling the plots**
#
# It can be done using the set_context() method. It allows us to override default parameters. This affects things like the size of the labels, lines, and other elements of the plot, but not the overall style. The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”. font_scale sets the font size.

# %%
sb.lineplot(x="tip", y="total_bill", data=df)
sb.set_context("paper")
plt.show()

# %%
with sb.axes_style('darkgrid'):
    plt.subplot(211)
    sb.lineplot(x="tip", y="total_bill", data=df)
    plt.show()
plt.subplot(212)
sb.lineplot(x="tip", y="total_bill", data=df)
plt.show()

# %% [markdown]
# **Color Palette**
#
# color_palette() method is used to give colors to the plot. Another function palplot() is used to deal with the color palettes and plots the color palette as a horizontal array.

# %%
palette = sb.color_palette()
  
# plots the color palette as a
# horizontal array
sb.palplot(palette)
  
plt.show()

# %% [markdown]
# **Diverging Color Palette**
#
#
# This type of color palette uses two different colors where each color depicts different points ranging from a common point in either direction. Consider a range of -10 to 10 so the value from -10 to 0 takes one color and values from 0 to 10 take another.

# %%
palette = sb.color_palette('PiYG', 11)
  
# diverging color palette
sb.palplot(palette)
  
plt.show()

# %% [markdown]
# **Sequential Color Palette**
#
# A sequential palette is used where the distribution ranges from a lower value to a higher value. To do this add the character ‘s’ to the color passed in the color palette.

# %%
palette = sb.color_palette('Greens', 15)
  
# sequential color palette
sb.palplot(palette)
  
plt.show()

# %% [markdown]
# Using add_axes() method

# %%
fig = plt.figure(figsize =(5, 4)) 
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
sb.lineplot(x="tip", y="total_bill", data=df)
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
sb.lineplot(x="tip", y="total_bill", data=df)
plt.show()

# %% [markdown]
# Using subplot() method

# %%
plt.subplot(121)
sb.lineplot(x="tip", y="total_bill", data=df)
  
plt.subplot(122)
sb.lineplot(x="tip", y="total_bill", data=df)
  
plt.show()

# %% [markdown]
# Using subplot2grid() method

# %%
axes1 = plt.subplot2grid (
  (7, 2), (0, 0), rowspan = 2,  colspan = 1) 
sb.lineplot(x="tip", y="total_bill", data=df)
  
axes2 = plt.subplot2grid (
  (7, 1), (2, 0), rowspan = 2, colspan = 1) 
sb.lineplot(x="tip", y="total_bill", data=df)
    
axes3 = plt.subplot2grid (
  (7, 1), (4, 0), rowspan = 2, colspan = 1)
sb.lineplot(x="tip", y="total_bill", data=df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
#  Using FacetGrid() method

# %%
plot = sb.FacetGrid(df, col="sex",row="smoker")
plot.map(plt.plot, "tip")
  
plt.show()

# %%
plot = sb.FacetGrid(df, col="sex",row="size")
plot.map(plt.plot, "tip")
  
plt.show()

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
plot = sb.FacetGrid(df, hue="sex")
plot.map(plt.plot, "tip")
plt.show()

# %%
############# Main Section         #############
# Form a facetgrid using columns with a hue
graph = sb.FacetGrid(df, col ="sex",  hue ="day")
# map the above form facetgrid with some attributes
graph.map(plt.scatter, "total_bill", "tip", edgecolor ="w").add_legend()
# show the object
plt.show()

# %%
# Form a facetgrid using columns with a hue
graph = sb.FacetGrid(df, row ='smoker', col ='time')
# map the above form facetgrid with some attributes
graph.map(plt.hist, 'total_bill', bins = 15, color ='orange')
# show the object
plt.show()

# %%
# Form a facetgrid using columns with a hue
graph = sb.FacetGrid(df, col ='time', hue ='smoker')
# map the above form facetgrid with some attributes
graph.map(sb.regplot, "total_bill", "tip").add_legend()
# show the object
plt.show()

# %% [markdown]
# Using PairGrid() method

# %%
plot = sb.PairGrid(df)
plot.map(plt.plot)
  
plt.show()

# %%
# PairGrid object with hue
graph = sb.PairGrid(df, hue ='day')
# type of graph for diagonal
graph = graph.map_diag(plt.hist)
# type of graph for non-diagonal
graph = graph.map_offdiag(plt.scatter)
# to add legends
graph = graph.add_legend()
# to show
plt.show()

# %%
# PairGrid object with hue
graph = sb.PairGrid(df)
# type of graph for non-diagonal(upper part)
graph = graph.map_upper(sb.scatterplot)
# type of graph for non-diagonal(lower part)
graph = graph.map_lower(sb.kdeplot)
# type of graph for diagonal
graph = graph.map_diag(sb.kdeplot, lw = 2)
# to show
plt.show()

# %% [markdown]
# **Relplot()**
#
#
# This function provides us the access to some other different axes-level functions which shows the relationships between two variables with semantic mappings of subsets. It is plotted using the relplot() method

# %%
sb.relplot(x='tip', y='sex', data=df)
  
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.relplot(x='total_bill', y='size', data=df)
  
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
sb.scatterplot(x='tip', y='total_bill', data=df)
plt.show()

# %% [markdown]
# lineplot

# %%
sb.lineplot(x='tip', y='total_bill', data=df)
plt.show()

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# **Bar Plot**

# %%
sb.barplot(x='sex', y='tip', data=df)
plt.show()

# %% [markdown]
# **Count Plot**

# %%
sb.countplot(x='sex', data=df)
plt.show()

# %%
df["tip"]
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %% [markdown]
# **Box Plot**
#
#
# A boxplot is sometimes known as the box and whisker plot.It shows the distribution of the quantitative data that represents the comparisons between variables. boxplot shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution i.e. the dots indicating the presence of outliers. It is created using the boxplot() method.

# %%
sb.boxplot(x='sex', y='tip', data=df)
plt.show()

# %% [markdown]
# **Violinplot**
#
#
# It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel density estimation to give a better description about the data distribution. It is created using the violinplot() method.

# %%
sb.violinplot(x='sex', y='tip', data=df)
plt.show()

# %% [markdown]
# **Stripplot**
#
#
# It basically creates a scatter plot based on the category. It is created using the stripplot() method.

# %%
sb.stripplot(x='sex', y='total_bill', data=df)
plt.show()

# %% [markdown]
# **Swarmplot**
#
#
# Swarmplot is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap.Some people also like combining the idea of a violin plot and a stripplot to form this plot. One drawback to using swarmplot is that sometimes they dont scale well to really large numbers and takes a lot of computation to arrange them. So in case we want to visualize a swarmplot properly we can plot it on top of a violinplot. It is plotted using the swarmplot() method.

# %%
sb.swarmplot(x='sex', y='total_bill', data=df)
plt.show()

# %% [markdown]
# # Distribution Plots
#
#
# Distribution Plots are used for examining univariate and bivariate distributions meaning such distributions that involve one variable or two discrete variables.

# %% [markdown]
# **Histogram**
#
#
#
# A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical representation of numerical data distribution. It can be plotted using the histplot() function.

# %%
sb.histplot(x='sex', y='total_bill', data=df)
plt.show()

# %% [markdown]
# **Distplot**
#
#
# Distplot is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we choose one particular column of the dataset. It is potted using the distplot() method.

# %%
sb.distplot(df['tip'])
plt.show()
# Out:
# C:\Users\vengadesh\AppData\Local\Temp\ipykernel_11956\1089851659.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['tip'])

# %% [markdown]
# **Jointplot**
#
#
# Jointplot is used to draw a plot of two variables with bivariate and univariate graphs. It basically combines two different plots. It is plotted using the jointplot() method.

# %%
sb.jointplot(x='sex', y='total_bill', data=df)
plt.show()

# %% [markdown]
# Pairplot
#
#
# Pairplot represents pairwise relation across the entire dataframe and supports an additional argument called hue for categorical separation. What it does basically is create a jointplot between every possible numerical column and takes a while if the dataframe is really huge. It is plotted using the pairplot() method.

# %%
sb.pairplot(data=df, hue='sex')
plt.show()

# %% [markdown]
# **Rugplot**
#
#
# Rugplot plots datapoints in an array as sticks on an axis.Just like a distplot it takes a single column. Instead of drawing a histogram it creates dashes all across the plot. If you compare it with the joinplot you can see that what a jointplot does is that it counts the dashes and shows it as bins. It is plotted using the rugplot() method.

# %%
sb.rugplot(data=df)
plt.show()

# %% [markdown]
# **KDE Plot**
#
#
#
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.

# %%
sb.kdeplot(x='tip', y='total_bill', data=df)
plt.show()

# %% [markdown]
# **Regression Plots**
#
#
#
# The regression plots are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses. Regression plots as the name suggests creates a regression line between two parameters and helps to visualize their linear relationships.

# %% [markdown]
# **lmplot**
#
#
# lmplot() method can be understood as a function that basically creates a linear model plot. It creates a scatter plot with a linear fit on top of it.

# %%
sb.lmplot(x='total_bill', y='tip', data=df)
plt.show()

# %% [markdown]
# **Regplot**
#
#
# regplot() method is also similar to lmplot which creates linear regression model.

# %%
sb.regplot(x='total_bill', y='tip', data=df)
plt.show()

# %% [markdown]
# **Note:** The difference between both the function is that regplot accepts the x, y variables in different format including NumPy arrays, Pandas objects, whereas, the lmplot only accepts the value as strings.

# %% [markdown]
# **Matrix Plots**
#
#
# A matrix plot means plotting matrix data where color coded diagrams shows rows data, column data and values. It can shown using the heatmap and clustermap.

# %% [markdown]
# **Heatmap**
#
#
# Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. it can be plotted using the heatmap() function.

# %%
tc = df.corr()
sb.heatmap(tc)
plt.show()
# Out:
# C:\Users\vengadesh\AppData\Local\Temp\ipykernel_11956\2788468058.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc = df.corr()

# %% [markdown]
# **Clustermap**
#
#
# The clustermap() function of seaborn plots the hierarchically-clustered heatmap of the given matrix dataset. Clustering simply means grouping data based on relationship among the variables in the data.

# %%
tc = df.corr()
  
sb.clustermap(tc)
plt.show()
# Out:
# C:\Users\vengadesh\AppData\Local\Temp\ipykernel_11956\3526271119.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tc = df.corr()
