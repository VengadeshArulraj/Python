# %% [markdown]
# **BeautifulSoup**
# pip install bs4

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://www.angelo.edu/faculty/kboudrea/periodic/structure_numbers.htm").content
soup_page = BeautifulSoup(page,'lxml')
# table = soup_page.find("td align")   #table = soup_page.find("table",{"class"":"align"})
# table_align = table.find("align")  #thead = table.find("thead").find_all("th")
a= soup_page
print(soup_page)
# print(table)
# print(table)
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Kevin A. Boudreaux" name="Author"/>
# <meta content="Information about various chemical compounds and elements" name="Description"/>
# <meta content="Microsoft FrontPage 6.0" name="GENERATOR"/>
# <meta content="Chemistry, Organic, Inorganic, Molecules, Elements, Periodic Table" name="Keywords"/>
# <meta content="FrontPage.Editor.Document" name="ProgId"/>
# <title>The Parts of the Periodic Table</title>
# <style>
# <!--
# table        { font-size: 12pt }
# body         { font-size: 12pt }
# -->
# </style>
# <base target="_self"/>
# </head>
# <body>
# <h3 align="center">Atomic Numbers</h3>
# <div align="center">
# <center>
# ...
